# %% [markdown]
# # Final Project - Word Cloud

# %% [markdown]
# For this project, you'll create a "word cloud" from a text by writing a script.  This script needs to process the text, remove punctuation, ignore case and words that do not contain all alphabets, count the frequencies, and ignore uninteresting or irrelevant words.  A dictionary is the output of the `calculate_frequencies` function.  The `wordcloud` module will then generate the image from your dictionary.

# %% [markdown]
# For the input text of your script, you will need to provide a file that contains text only.  For the text itself, you can copy and paste the contents of a website you like.  Or you can use a site like [Project Gutenberg](https://www.gutenberg.org/) to find books that are available online.  You could see what word clouds you can get from famous books, like a Shakespeare play or a novel by Jane Austen. Save this as a .txt file somewhere on your computer.
# <br><br>
# Now you will need to upload your input file here so that your script will be able to process it.  To do the upload, you will need an uploader widget.  Run the following cell to perform all the installs and imports for your word cloud script and uploader widget.  It may take a minute for all of this to run and there will be a lot of output messages. But, be patient. Once you get the following final line of output, the code is done executing. Then you can continue on with the rest of the instructions for this notebook.
# <br><br>
# **Enabling notebook extension fileupload/extension...**
# <br>
# **- Validating: <font color =green>OK</font>**

# %%
# Here are all the installs and imports you will need for your word cloud script and uploader widget

# !pip install wordcloud
# !pip install fileupload
# !pip install ipywidgets
# !jupyter nbextension install --py --user fileupload
# !jupyter nbextension enable --py fileupload

import wordcloud
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display
import fileupload
import io
import sys
# Out:
# Requirement already satisfied: wordcloud in c:\python310\lib\site-packages (1.9.2)
# Requirement already satisfied: pillow in c:\python310\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in c:\python310\lib\site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\python310\lib\site-packages (from wordcloud) (1.24.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib->wordcloud) (4.37.1)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: fileupload in c:\python310\lib\site-packages (0.1.5)
# Requirement already satisfied: ipywidgets>=5.1 in c:\python310\lib\site-packages (from fileupload) (8.0.4)
# Requirement already satisfied: notebook>=4.2 in c:\python310\lib\site-packages (from fileupload) (6.5.4)
# Requirement already satisfied: traitlets>=4.2 in c:\users\hp\appdata\roaming\python\python310\site-packages (from fileupload) (5.8.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipywidgets>=5.1->fileupload) (8.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\python310\lib\site-packages (from ipywidgets>=5.1->fileupload) (4.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipywidgets>=5.1->fileupload) (6.19.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\python310\lib\site-packages (from ipywidgets>=5.1->fileupload) (3.0.5)
# Requirement already satisfied: nbformat in c:\python310\lib\site-packages (from notebook>=4.2->fileupload) (5.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\python310\lib\site-packages (from notebook>=4.2->fileupload) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\python310\lib\site-packages (from notebook>=4.2->fileupload) (1.0.0)
# Requirement already satisfied: nbconvert>=5 in c:\python310\lib\site-packages (from notebook>=4.2->fileupload) (7.4.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\hp\appdata\roaming\python\python310\site-packages (from notebook>=4.2->fileupload) (1.5.6)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\hp\appdata\roaming\python\python310\site-packages (from notebook>=4.2->fileupload) (7.4.8)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\appdata\roaming\python\python310\site-packages (from notebook>=4.2->fileupload) (24.0.1)
# Requirement already satisfied: ipython-genutils in c:\python310\lib\site-packages (from notebook>=4.2->fileupload) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\python310\lib\site-packages (from notebook>=4.2->fileupload) (1.8.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from notebook>=4.2->fileupload) (6.2)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from notebook>=4.2->fileupload) (5.1.0)
# Requirement already satisfied: argon2-cffi in c:\python310\lib\site-packages (from notebook>=4.2->fileupload) (21.3.0)
# Requirement already satisfied: jinja2 in c:\python310\lib\site-packages (from notebook>=4.2->fileupload) (3.1.2)
# Requirement already satisfied: prometheus-client in c:\python310\lib\site-packages (from notebook>=4.2->fileupload) (0.17.0)
# Requirement already satisfied: psutil in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (5.9.4)
# Requirement already satisfied: packaging in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (21.3)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.6.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.1.6)
# Requirement already satisfied: stack-data in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.6.2)
# Requirement already satisfied: backcall in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.4.6)
# Requirement already satisfied: decorator in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (2.13.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (3.0.36)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.18.2)
# Requirement already satisfied: entrypoints in c:\users\hp\appdata\roaming\python\python310\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->fileupload) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->fileupload) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\python310\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.2->fileupload) (304)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\appdata\roaming\python\python310\site-packages (from jupyter-core>=4.6.1->notebook>=4.2->fileupload) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in c:\python310\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.2.3)
# Requirement already satisfied: jupyter-server>=1.8 in c:\python310\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->fileupload) (2.6.0)
# Requirement already satisfied: tinycss2 in c:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in c:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (4.11.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (1.5.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (2.0.5)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (2.1.1)
# Requirement already satisfied: defusedxml in c:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (0.8.0)
# Requirement already satisfied: bleach in c:\python310\lib\site-packages (from nbconvert>=5->notebook>=4.2->fileupload) (6.0.0)
# Requirement already satisfied: fastjsonschema in c:\python310\lib\site-packages (from nbformat->notebook>=4.2->fileupload) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\python310\lib\site-packages (from nbformat->notebook>=4.2->fileupload) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\python310\lib\site-packages (from terminado>=0.8.3->notebook>=4.2->fileupload) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\python310\lib\site-packages (from argon2-cffi->notebook>=4.2->fileupload) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\python310\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\python310\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (0.19.3)
# Requirement already satisfied: jupyter-server-terminals in c:\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.4.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (3.7.0)
# Requirement already satisfied: overrides in c:\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (7.3.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.6.3)
# Requirement already satisfied: websocket-client in c:\python310\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (1.5.2)
# Requirement already satisfied: wcwidth in c:\python310\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook>=4.2->fileupload) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\python310\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.2->fileupload) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\python310\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.2->fileupload) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\python310\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (3.0.9)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (1.2.0)
# Requirement already satisfied: pure-eval in c:\users\hp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=5.1->fileupload) (2.2.1)
# Requirement already satisfied: exceptiongroup in c:\python310\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (1.1.1)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\appdata\roaming\python\python310\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\python310\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (1.3.0)
# Requirement already satisfied: pycparser in c:\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (2.21)
# Requirement already satisfied: rfc3339-validator in c:\python310\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.1.4)
# Requirement already satisfied: pyyaml>=5.3 in c:\python310\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (6.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\python310\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\python310\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->fileupload) (0.1.1)
# Requirement already satisfied: isoduration in c:\python310\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (20.11.0)
# Requirement already satisfied: uri-template in c:\python310\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.2.0)
# Requirement already satisfied: fqdn in c:\python310\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.5.1)
# Requirement already satisfied: webcolors>=1.11 in c:\python310\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.13)
# Requirement already satisfied: jsonpointer>1.13 in c:\python310\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (2.3)
# Requirement already satisfied: arrow>=0.15.0 in c:\python310\lib\site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.2->fileupload) (1.2.3)
# Requirement already satisfied: ipywidgets in c:\python310\lib\site-packages (8.0.4)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\python310\lib\site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipywidgets) (6.19.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\python310\lib\site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipywidgets) (5.8.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipywidgets) (8.7.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.8)
# Requirement already satisfied: nest-asyncio in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.4)
# Requirement already satisfied: psutil in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: packaging in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: decorator in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: pickleshare in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: backcall in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: stack-data in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\hp\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.1.0)
# Requirement already satisfied: entrypoints in c:\users\hp\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: wcwidth in c:\python310\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\python310\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: pure-eval in c:\users\hp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: six in c:\python310\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\appdata\roaming\python\python310\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.6.0)
# Requirement already satisfied: pywin32>=1.0 in c:\python310\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (304)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -9p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -8p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -7p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -6p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -5p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -4p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -3p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -1p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -0p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Installing C:\Python310\lib\site-packages\fileupload\static -> fileupload
# Up to date: C:\Users\hp\AppData\Roaming\jupyter\nbextensions\fileupload\extension.js
# Up to date: C:\Users\hp\AppData\Roaming\jupyter\nbextensions\fileupload\widget.js
# Up to date: C:\Users\hp\AppData\Roaming\jupyter\nbextensions\fileupload\fileupload\widget.js
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable fileupload --user --py
#
# Enabling notebook extension fileupload/extension...
#       - Validating: ok

# %% [markdown]
# Whew! That was a lot. All of the installs and imports for your word cloud script and uploader widget have been completed.
# <br><br>
# **IMPORTANT!** If this was your first time running the above cell containing the installs and imports, you will need save this notebook now. Then under the File menu above,  select Close and Halt. When the notebook has completely shut down, reopen it. This is the only way the necessary changes will take affect.
# <br><br>
# To upload your text file, run the following cell that contains all the code for a custom uploader widget. Once you run this cell, a "Browse" button should appear below it. Click this button and navigate the window to locate your saved text file.

# %%
# This is the uploader widget

def _upload():

    _upload_widget = fileupload.FileUploadWidget()

    def _cb(change):
        global file_contents
        decoded = io.StringIO(change['owner'].data.decode('utf-8'))
        filename = change['owner'].filename
        print('Uploaded `{}` ({:.2f} kB)'.format(
            filename, len(decoded.read()) / 2 **10))
        file_contents = decoded.getvalue()

    _upload_widget.observe(_cb, names='data')
    display(_upload_widget)

_upload()
# Out:
# FileUploadWidget(label='Browse', _dom_classes=('widget_item', 'btn-group'))

# %% [markdown]
# The uploader widget saved the contents of your uploaded file into a string object named *file_contents* that your word cloud script can process. This was a lot of preliminary work, but you are now ready to begin your script.

# %% [markdown]
# Write a function in the cell below that iterates through the words in *file_contents*, removes punctuation, and counts the frequency of each word.  Oh, and be sure to make it ignore word case, words that do not contain all alphabets and boring words like "and" or "the".  Then use it in the `generate_from_frequencies` function to generate your very own word cloud!
# <br><br>
# **Hint:** Try storing the results of your iteration in a dictionary before passing them into wordcloud via the `generate_from_frequencies` function.

# %%
def calculate_frequencies(file_contents):
    # Here is a list of punctuations and uninteresting words you can use to process your text
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    uninteresting_words = ["the", "a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
    "we", "our", "ours", "you", "your", "yours", "he", "she", "him", "his", "her", "hers", "its", "they", "them", \
    "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being", \
    "have", "has", "had", "do", "does", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
    "all", "any", "both", "each", "few", "more", "some", "such", "no", "nor", "too", "very", "can", "will", "just"]
    
    # LEARNER CODE START HERE
    result = {}
    a = file_contents.split()
    for word in a:
        if word in uninteresting_words:
            pass
        else:
            for letter in word:
                if letter in punctuations:
                    letter.replace(punctuations,"")
            if word not in result.keys():
                result[word]=0
            else:
                result[word]+=1
   # print(result)

    
    #wordcloud
    cloud = wordcloud.WordCloud()
    cloud.generate_from_frequencies(result)
    return cloud.to_array()

# %% [markdown]
# If you have done everything correctly, your word cloud image should appear after running the cell below.  Fingers crossed!

# %%
# Display your wordcloud image
myimage = calculate_frequencies(file_contents)
plt.imshow(myimage, interpolation = 'nearest')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Display your wordcloud image
#       2 file_contents = ("Selected Poems of Oscar Wilde.txt")
# ----> 3 myimage = calculate_frequencies("Selected Poems of Oscar Wilde.txt")
#       4 plt.imshow(myimage, interpolation = 'nearest')
#       5 plt.axis('off')
#
# Cell In[5], line 29, in calculate_frequencies(file_contents)
#      24 # print(result)
#      25
#      26
#      27  #wordcloud
#      28  cloud = wordcloud.WordCloud()
# ---> 29  cloud.generate_from_frequencies(result)
#      30  return cloud.to_array()
#
# File c:\Python310\lib\site-packages\wordcloud\wordcloud.py:417, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     414 # largest entry will be 1
#     415 max_frequency = float(frequencies[0][1])
# --> 417 frequencies = [(word, freq / max_frequency)
#     418                for word, freq in frequencies]
#     420 if self.random_state is not None:
#     421     random_state = self.random_state
#
# File c:\Python310\lib\site-packages\wordcloud\wordcloud.py:417, in <listcomp>(.0)
#     414 # largest entry will be 1
#     415 max_frequency = float(frequencies[0][1])
# --> 417 frequencies = [(word, freq / max_frequency)
#     418                for word, freq in frequencies]
#     420 if self.random_state is not None:
#     421     random_state = self.random_state
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# If your word cloud image did not appear, go back and rework your `calculate_frequencies` function until you get the desired output.  Definitely check that you passed your frequecy count dictionary into the `generate_from_frequencies` function of `wordcloud`. Once you have correctly displayed your word cloud image, you are all done with this project. Nice work!
